# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt 

import torch
import os
from IPython.display import Image, clear_output
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9848, done.
# remote: Total 9848 (delta 0), reused 0 (delta 0), pack-reused 9848
# Receiving objects: 100% (9848/9848), 10.23 MiB | 17.57 MiB/s, done.
# Resolving deltas: 100% (6818/6818), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 11.6 MB/s

# %%
# Requires uploading of dataset to Google Drive and changes to config file. 
# !python train.py --img 640 --batch 16 --epochs 100 --cfg /content/yolov5/models/yolov5s.yaml --hyp /content/yolov5/data/hyps/hyp.scratch.yaml --data /content/yolov5/data/shapes.yaml --weights yolov5s.pt --cache --name trial_01
# Out:
# train: weights=yolov5s.pt, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/yolov5/data/shapes.yaml, hyp=/content/yolov5/data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=trial_01, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.0-39-g5d4258f torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/MicroIntelligence/shapes_dataset/val/images --weights /content/yolov5/runs/train/trial_01/weights/best.pt --conf 0.25 --name trial_01
# Out:
# detect: weights=['/content/yolov5/runs/train/trial_01/weights/best.pt'], source=/content/drive/MyDrive/MicroIntelligence/shapes_dataset/val/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=trial_01, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-39-g5d4258f torch 1.9.0+cu111 CUDA:0 (Tesla K80, 11441.1875MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/50 /content/drive/MyDrive/MicroIntelligence/shapes_dataset/val/images/Image_20211022144253438.jpg: 544x640 1 Pent, Done. (0.034s)
# image 2/50 /content/drive/MyDrive/MicroIntelligence/shapes_dataset/val/images/Image_20211022144312834.jpg: 544x640 1 Pent, Done. (0.032s)
# ...
